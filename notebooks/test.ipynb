# %%
# %load_ext autoreload
# %autoreload 2

# %%
import MiniOCR

# %%
model = MiniOCR.Model()
model.predict("test2.jpeg",)
# Out:
# [{'text': '6A', 'score': 0.8828625132332668},
#  {'text': '6N', 'score': 0.8368727362876172},
#  {'text': 'GA', 'score': 0.8302653136825455},
#  {'text': '68', 'score': 0.8176551276281536},
#  {'text': '6K', 'score': 0.8156228782897479},
#  {'text': '6k', 'score': 0.8156228782897479},
#  {'text': '6H', 'score': 0.8150485517909871},
#  {'text': '6X', 'score': 0.8150485517909871},
#  {'text': '6x', 'score': 0.8150485517909871},
#  {'text': '5A', 'score': 0.8137334632495019},
#  {'text': 'SA', 'score': 0.8137334632495019},
#  {'text': 'sA', 'score': 0.8137334632495019},
#  {'text': 'EA', 'score': 0.8133302693945055},
#  {'text': '6q', 'score': 0.8102773095152358},
#  {'text': '6P', 'score': 0.8079800035201927},
#  {'text': '6p', 'score': 0.8079800035201927},
#  {'text': 'BA', 'score': 0.8049523082858379},
#  {'text': 'bA', 'score': 0.8049523082858379},
#  {'text': 'GN', 'score': 0.7870154123563111},
#  {'text': 'co', 'score': 0.7852128222204158},
# ...
